# %%
import pandas as pd
import numpy as np

# %%
original_data = pd.read_csv?

# %%
original_data = pd.read_csv("breakdownlist.csv", sep = ';')

# %%
original_data
# Out:
#       id cncmachine      cause  personnelid          starting  \
# 0      1        M31   Cleaning         25.0   6.02.2018 14:00
# 1      2        M34  breakdown         14.0  22.02.2018 17:22
# 2      3        M38   Cleaning         35.0  29.03.2018 15:02
# 3      4        M35   Cleaning         39.0   7.04.2018 09:43
# 4      5        M39  breakdown          3.0  10.04.2018 13:02
# 5      6        TG3  breakdown         37.0  12.04.2018 12:38
# 6      7        NaN        NaN          NaN  13.04.2018 10:04
# 7      8        M03  breakdown         39.0  13.04.2018 10:05
# 8      9        M03  breakdown         39.0  18.04.2018 13:44
# 9     10        M35      other         39.0  18.04.2018 18:17
# 10    11        M38    trouble         43.0  20.04.2018 12:02
# 11    12        NaN        NaN          NaN  20.04.2018 12:23
# 12    13        NaN        NaN          NaN   9.05.2018 14:28
# 13    14        M03   Cleaning         39.0  10.05.2018 09:35
# ...
